# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
spawn_10 = [71, 71, 73, 80, 76, 82, 84, 85, 86, 87, 87, 81, 80, 78, 78, 78, 77, 76, 79, 79, 78, 81, 80, 83, 83, 83, 74, 74, 74, 74, 76, 75, 75, 76, 77, 73, 75, 77, 77, 78, 79, 83, 86, 86, 87, 85, 87, 88, 87, 88, 86, 75, 84, 86, 86, 82, 79, 76, 77, 82]

# %%
spawn_15 = [43, 42, 40, 42, 40, 43, 42, 42, 44, 46, 47, 46, 46, 46, 47, 47, 47, 48, 48, 49, 45, 48, 48, 48, 49, 47, 44, 44, 44, 45, 44, 44, 45, 45, 46, 47, 43, 47, 47, 47, 46, 45, 45, 46, 46, 47, 46, 46, 47, 47, 47, 46, 44, 47, 47, 44, 42, 42, 45, 45]

# %%
spawn_20 = [31, 31, 31, 31, 31, 31, 31, 30, 33, 33, 33, 33, 34, 34, 33, 33, 31, 32, 34, 34, 33, 35, 34, 32, 34, 34, 34, 35, 34, 35, 35, 36, 36, 37, 34, 32, 32, 32, 31, 30, 32, 32, 31, 31, 31, 32, 31, 32, 32, 31, 31, 31, 32, 32, 30, 33, 33, 33, 33, 33]

# %%
spawn_25 = [22, 23, 23, 23, 24, 24, 24, 25, 25, 25, 25, 25, 26, 26, 26, 24, 25, 25, 25, 26, 26, 24, 24, 24, 24, 24, 24, 24, 23, 24, 24, 22, 23, 24, 24, 24, 24, 24, 24, 25, 25, 26, 25, 25, 26, 25, 25, 24, 26, 26, 25, 24, 24, 25, 25, 25, 25, 25, 25, 25]

# %%
spawn_30 = [17, 16, 16, 17, 18, 17, 16, 18, 19, 18, 18, 18, 17, 18, 18, 18, 18, 19, 19, 18, 18, 17, 18, 17, 19, 19, 18, 17, 18, 19, 19, 19, 19, 19, 20, 19, 20, 20, 20, 20, 19, 19, 18, 17, 19, 18, 18, 18, 18, 18, 18, 18, 18, 18, 19, 18, 17, 17, 16, 17]

# %%
spawn_35 = [14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 14, 15, 15, 15, 15, 15, 16, 15, 15, 14, 14, 14, 14, 14, 14, 13, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]

# %%
spawn_40 = [12, 12, 12, 12, 12, 12, 12, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 11, 12, 12, 12, 12, 12, 12, 12, 13, 12, 13, 13, 13, 13, 13, 12]

# %%
vehicles_amounts = [spawn_10,spawn_15,spawn_20,spawn_25,spawn_30,spawn_35,spawn_40]
fig = plt.figure(figsize=(15,10))
plt.title('Total vehicles spawned effect on the maximum loops the simulation \n can run each second', fontsize=17)
plt.xlabel('Vehicles spawned', fontsize=15)
plt.ylabel('Loops per second', fontsize=15)
x = [10,15,20,25,30,35,40]
plt.boxplot(vehicles_amounts, labels = x)
plt.show()
