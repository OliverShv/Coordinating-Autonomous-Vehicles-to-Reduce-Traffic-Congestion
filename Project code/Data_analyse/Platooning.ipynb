# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
spawn_10 = [70, 71, 74, 76, 71, 76, 75, 74, 75, 75, 77, 79, 74, 72, 73, 74, 77, 77, 76, 76, 72, 76, 77, 76, 77, 77, 76, 74, 74, 76, 75, 76, 75, 74, 75, 77, 73, 78, 76, 77, 79, 79, 71, 73, 72, 71, 72, 72, 72, 72, 72, 70, 66, 71, 70, 71, 71, 68, 68, 71]

# %%
spawn_15 = [43, 44, 45, 44, 44, 44, 45, 46, 46, 47, 47, 43, 42, 42, 42, 42, 41, 42, 43, 43, 43, 43, 44, 44, 44, 44, 44, 41, 44, 45, 45, 45, 45, 45, 45, 45, 44, 45, 45, 46, 45, 45, 41, 41, 42, 43, 43, 43, 41, 42, 42, 43, 43, 43, 43, 43, 44, 44, 42, 44]

# %%
spawn_20 = [29, 28, 29, 29, 29, 29, 29, 29, 28, 30, 30, 31, 30, 31, 31, 30, 31, 31, 31, 31, 31, 31, 31, 33, 30, 32, 33, 33, 33, 33, 33, 32, 32, 30, 29, 29, 29, 30, 30, 30, 28, 30, 30, 30, 30, 30, 31, 31, 30, 30, 30, 32, 33, 33, 33, 32, 32, 33, 33, 33]

# %%
spawn_25 = [22, 22, 20, 23, 24, 24, 24, 24, 24, 24, 24, 24, 24, 23, 23, 23, 23, 23, 21, 23, 22, 21, 21, 21, 21, 22, 22, 22, 23, 23, 23, 23, 24, 23, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 21, 22, 22, 20, 20, 20, 21, 21, 21, 22, 22, 22, 22, 22]

# %%
spawn_30 = [16, 16, 16, 16, 16, 16, 16, 15, 16, 15, 16, 16, 17, 17, 17, 17, 17, 17, 18, 18, 18, 18, 18, 19, 18, 17, 19, 19, 19, 19, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 17, 18, 18, 18, 17, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 15, 17, 17, 16]

# %%
spawn_35 = [12, 13, 13, 13, 13, 13, 12, 13, 13, 14, 14, 14, 14, 14, 14, 14, 15, 15, 15, 15, 14, 13, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 13, 13, 12, 12, 12, 12, 13, 13, 13, 12, 12, 12, 12, 12, 12, 13, 12, 13, 12, 13, 13, 13, 14, 14, 14, 14]

# %%
spawn_40 = [10, 11, 10, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 12, 12, 11, 11, 10, 10, 11, 10, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 12, 12, 12, 12, 12, 12, 12, 11, 11, 11, 11, 11, 11, 11, 11, 11]

# %%
vehicles_amounts = [spawn_10,spawn_15,spawn_20,spawn_25,spawn_30,spawn_35,spawn_40]
fig = plt.figure(figsize=(15,10))
plt.title('Total vehicles spawned effect on the maximum loops the simulation \n can run each second with platooning enabled', fontsize=17)
plt.xlabel('Vehicles spawned', fontsize=15)
plt.ylabel('Loops per second', fontsize=15)
x = [10,15,20,25,30,35,40]
plt.boxplot(vehicles_amounts, labels = x)
plt.show()
